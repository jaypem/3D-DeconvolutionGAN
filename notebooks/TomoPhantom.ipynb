# %%
# %matplotlib inline

import numpy as np
import sys
import matplotlib.pyplot as plt
import cv2

sys.path.insert(0, '../scripts')
import plot3DVol as plot3D
import helper as hp

sys.path.insert(0, '../scripts/NanoImagingPack')
from view import view, graph

path = r'C:\Users\praetoriusjanphilipp\AppData\Roaming\Python\Python36\site-packages'
sys.path.insert(0, path)
from tomophantom import TomoP2D
from tomophantom import TomoP3D

# %% [markdown]
# # 2D

# %%
model = 1
sizeN = 256
N_size = 10

path_to_repo_2D = r'U:\repos\TomoPhantom\functions\models\Phantom2DLibrary.dat'

#This will generate 256x256 phantom from model no.1
phantom = TomoP2D.Model(model, sizeN, path_to_repo_2D)

angles_num = int(0.5*np.pi*N_size); # angles number
angles = np.linspace(0,180,angles_num,dtype='float32')
angles_rad = angles*(np.pi/180)
P = int(np.sqrt(2)*N_size) #detectors

# %%
#This will generate a sinogram of model no.1
sino_an = TomoP2D.ModelSino(model, N_size, P, angles, path_to_repo_2D)
plt.imshow(sino_an)

# %% [markdown]
# # 3D

# %%
model = 1
sizeN = 64
N_size = 10

path_to_repo_3D = r'U:\repos\TomoPhantom\functions\models\Phantom3DLibrary.dat'

#This will generate 256x256 phantom from model no.1
panthom = TomoP3D.Model(model, sizeN, path_to_repo_3D)

angles_num = int(0.5*np.pi*N_size); # angles number
angles = np.linspace(0,180,angles_num,dtype='float32')
angles_rad = angles*(np.pi/180)
P = int(np.sqrt(2)*N_size) #detectors

hp.print_volume_statistics(panthom, "panthom")
# Out:
# name:	 panthom
# shape:	 (64, 64, 64)
# min:	 0.0
# median:	 0.0
# mean:	 0.0
# max:	 1.0

# %% [markdown]
# # Plot

# %%
# %matplotlib inline

plt.imshow(panthom[:,:,30], cmap='gray')

# %%
# %matplotlib notebook

vol_3D = plot3D.Interactive_3DVolume(vol=panthom)
vol_3D.multi_slice_viewer()
# Out:
# volume shapes before / after: (64, 64, 64) / (64, 64, 64)
# for change the stack use keys: {k,j}
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib notebook

v = view(phantom, show_hist=False)
# Out:
# <img src="data:image/png;base64,..." width="431.818172458775">
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:2918: UserWarning:
#
# Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
